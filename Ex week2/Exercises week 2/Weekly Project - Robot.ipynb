# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# With the OpenCV we can load in a video using the cv2.VideoCapture function:
cap = cv2.VideoCapture('Robots.mp4')

# %%
# When we need a single frame of the video, we can then use the read function:
# The variable "ret" will be either True or False indicating if the frame was read correct.
# The variable "frame" will then be the first frame of the video. 
# # If we call the same function again, it will return the second frame of the video, and so on.
# ret, frame = cap.read()
# # frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
# plt.imshow(frame)
# cv2.imshow('image', frame)
# k = cv2.waitKey(0)
# if k == 27:         # wait for ESC key to exit
#     cv2.destroyAllWindows()
# cap.release()
# # cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

cv2.namedWindow("frame", cv2.WINDOW_NORMAL)        # Create window with freedom of dimensions
# cv2.resizeWindow("frame", 400, 300) 

# With the OpenCV we can load in a video using the cv2.VideoCapture function:
cap = cv2.VideoCapture('Robots.mp4')

ret, old_frame = cap.read()
old_frame_gray = cv2.cvtColor(old_frame, cv2.COLOR_RGB2GRAY)
feat1 = cv2.goodFeaturesToTrack(old_frame_gray, maxCorners=50, qualityLevel=0.3, minDistance=30)

while ret == True:
    
    ret, frame = cap.read()
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    feat2, status, error = cv2.calcOpticalFlowPyrLK(old_frame_gray, frame_gray, feat1, None)
    
    # Select good points
    good_new = feat2[status==1]
    good_old = feat1[status==1]

    
    for i in range(len(feat1)):
        if (abs(feat1[i][0][0] - feat2[i][0][0]) > 5 or abs(feat1[i][0][1] - feat2[i][0][1]) > 5):
            cv2.line(frame, (feat1[i][0][0], feat1[i][0][1]), (feat2[i][0][0], feat2[i][0][1]), (0, 255, 0), 2)
            frame = cv2.circle(frame, (feat1[i][0][0], feat1[i][0][1]), 3, (0, 255, 0), -1)
    
    cv2.imshow('frame',frame)
    
    old_frame_gray = frame_gray.copy()
    feat1 = good_new.reshape(-1,1,2)
    
#     cv2.waitKey(50)
#     if cv2.waitKey(1) == 'k':
#         break
    k = cv2.waitKey(5)
    if k == 27:# wait for ESC key to exit
        ret = False
        cv2.destroyAllWindows()

cv2.destroyAllWindows()
cap.release()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-7d9a2f89a883> in <module>
#      16
#      17     ret, frame = cap.read()
# ---> 18     frame_gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
#      19     feat2, status, error = cv2.calcOpticalFlowPyrLK(old_frame_gray, frame_gray, feat1, None)
#      20
#
# error: OpenCV(3.4.2) c:\projects\opencv-python\opencv\modules\imgproc\src\color.hpp:253: error: (-215:Assertion failed) VScn::contains(scn) && VDcn::contains(dcn) && VDepth::contains(depth) in function 'cv::CvtHelper<struct cv::Set<3,4,-1>,struct cv::Set<1,-1,-1>,struct cv::Set<0,2,5>,2>::CvtHelper'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# With the OpenCV we can load in a video using the cv2.VideoCapture function:
cap = cv2.VideoCapture('Robots.mp4')

ret, frame = cap.read()

while ret == True:
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    feat1 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100, qualityLevel=0.3, minDistance=7)
    for i in range(len(feat1)):
        cv2.circle(frame, (feat1[i][0][0], feat1[i][0][1]), 3, (0, 255, 0), -1)
        
    cv2.imshow('frame',frame)
    cv2.waitKey(5)
    
    ret, frame = cap.read()

cv2.destroyAllWindows()
cap.release()

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture('Robots.mp4')

cv2.namedWindow("frame", cv2.WINDOW_NORMAL)
cv2.resizeWindow("frame", 400, 300)

ret, frame1 = cap.read()
prvs = cv2.cvtColor(frame1,cv.COLOR_BGR2GRAY)
hsv = np.zeros_like(frame1)
hsv[...,1] = 255

while ret == True:
    ret, frame2 = cap.read()
    next = cv2.cvtColor(frame2,cv2.COLOR_BGR2GRAY)
    flow = cv2.calcOpticalFlowFarneback(prvs,next, None, 0.5, 3, 15, 3, 5, 1.2, 0)
    mag, ang = cv2.cartToPolar(flow[...,0], flow[...,1])
    hsv[...,0] = ang*180/np.pi/2
    hsv[...,2] = cv2.normalize(mag,None,0,255,cv.NORM_MINMAX)
    bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
    cv2.imshow('frame',bgr)
    k = cv2.waitKey(5)
    if k == 27:
        ret = False
        cv2.destroyAllWindows()
    elif k == ord('s'):
        cv2.imwrite('opticalfb.png',frame2)
        cv2.imwrite('opticalhsv.png',bgr)
    prvs = next

cv2.destroyAllWindows()
cap.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-052606e59442> in <module>
#       8
#       9 ret, frame1 = cap.read()
# ---> 10 prvs = cv2.cvtColor(frame1,cv.COLOR_BGR2GRAY)
#      11 hsv = np.zeros_like(frame1)
#      12 hsv[...,1] = 255
#
# NameError: name 'cv' is not defined

# %%
import cv2
import sys

(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')

cv2.namedWindow("Tracking", cv2.WINDOW_NORMAL) 
cv2.resizeWindow("Tracking", 1200, 800)

if __name__ == '__main__' :

    # Set up tracker.
    # Instead of MIL, you can also use

    tracker_types = ['BOOSTING', 'MIL','KCF', 'TLD', 'MEDIANFLOW', 'GOTURN', 'MOSSE', 'CSRT']
    tracker_type = tracker_types[2]

    if int(minor_ver) < 3:
        tracker = cv2.Tracker_create(tracker_type)
    else:
        if tracker_type == 'BOOSTING':
            tracker = cv2.TrackerBoosting_create()
        if tracker_type == 'MIL':
            tracker = cv2.TrackerMIL_create()
        if tracker_type == 'KCF':
            tracker = cv2.TrackerKCF_create()
        if tracker_type == 'TLD':
            tracker = cv2.TrackerTLD_create()
        if tracker_type == 'MEDIANFLOW':
            tracker = cv2.TrackerMedianFlow_create()
        if tracker_type == 'GOTURN':
            tracker = cv2.TrackerGOTURN_create()
        if tracker_type == 'MOSSE':
            tracker = cv2.TrackerMOSSE_create()
        if tracker_type == "CSRT":
            tracker = cv2.TrackerCSRT_create()

    # Read video
    video = cv2.VideoCapture("Robots.mp4")

    # Exit if video not opened.
    if not video.isOpened():
        print ("Could not open video")
        sys.exit()

    # Read first frame.
    ret, frame = video.read()
    if not ok:
        print ('Cannot read video file')
        sys.exit()
    
    # Define an initial bounding box
    bbox = (287, 23, 86, 320)

    # Uncomment the line below to select a different bounding box
    bbox = cv2.selectROI(frame, False)

    # Initialize tracker with first frame and bounding box
    ok = tracker.init(frame, bbox)

    while ret == True:
        # Read a new frame
        ret, frame = video.read()
        if not ok:
            break
        
        # Start timer
        timer = cv2.getTickCount()

        # Update tracker
        ok, bbox = tracker.update(frame)

        # Calculate Frames per second (FPS)
        fps = cv2.getTickFrequency() / (cv2.getTickCount() - timer);

        # Draw bounding box
        if ok:
            # Tracking success
            p1 = (int(bbox[0]), int(bbox[1]))
            p2 = (int(bbox[0] + bbox[2]), int(bbox[1] + bbox[3]))
            cv2.rectangle(frame, p1, p2, (255,0,0), 2, 1)
        else :
            # Tracking failure
            cv2.putText(frame, "Tracking failure detected", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2)

        # Display tracker type on frame
        cv2.putText(frame, tracker_type + " Tracker", (100,20), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (50,170,50),2);
    
        # Display FPS on frame
        cv2.putText(frame, "FPS : " + str(int(fps)), (100,50), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (50,170,50), 2);

        # Display result
        cv2.imshow("Tracking", frame)

        # Exit if ESC pressed
        k = cv2.waitKey(1) & 0xff
        if k == 27: break
cv2.destroyAllWindows()
cap.release()
# Out:
# Cannot read video file
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\users\benti\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3435: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture('Robots.mp4')
cv2.namedWindow("frame2", cv2.WINDOW_NORMAL) 
cv2.resizeWindow("frame2", 1200, 800)

# params for ShiTomasi corner detection
feature_params = dict( maxCorners = 100,
                       qualityLevel = 0.3,
                       minDistance = 7,
                       blockSize = 7 )

# Parameters for lucas kanade optical flow
lk_params = dict( winSize  = (15,15),
                  maxLevel = 2,
                  criteria = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03))

# Create some random colors
color = np.random.randint(0,255,(100,3))

# Take first frame and find corners in it
ret, old_frame = cap.read()
old_gray = cv2.cvtColor(old_frame, cv2.COLOR_BGR2GRAY)
p0 = cv2.goodFeaturesToTrack(old_gray, mask = None, **feature_params)

# Create a mask image for drawing purposes
mask = np.zeros_like(old_frame)
while ret == True:
    ret,frame = cap.read()
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # calculate optical flow
    p1, st, err = cv2.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)
    # Select good points
    good_new = p1[st==1]
    good_old = p0[st==1]
    # draw the tracks
    for i,(new,old) in enumerate(zip(good_new, good_old)):
        a,b = new.ravel()
        c,d = old.ravel()
        mask = cv2.line(mask, (a,b),(c,d), color[i].tolist(), 2)
        frame = cv2.circle(frame,(a,b),5,color[i].tolist(),-1)
    img = cv2.add(frame,mask)
    cv2.imshow('frame2',img)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        ret = False
        cv2.destroyAllWindows()
    # Now update the previous frame and previous points
    old_gray = frame_gray.copy()
    p0 = good_new.reshape(-1,1,2)
    
cv2.destroyAllWindows()
cap.release()
